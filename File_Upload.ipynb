# %%
import os
import pandas as pd
import warnings

# %%
from elasticsearch import Elasticsearch, helpers
import csv

# %%
username = "elastic"
password = "scFQhlmk=X6-QGnjHOd8"
es = Elasticsearch("https://35.178.90.186:9200", basic_auth=(username, password), verify_certs=False)
# Out:
# D:\ASUS\Anaconda\lib\site-packages\elasticsearch\_sync\client\__init__.py:395: SecurityWarning: Connecting to 'https://35.178.90.186:9200' using TLS with verify_certs=False is insecure
#   _transport = transport_class(

# %%
fname = 'onthemarket_dev.csv'
with open(fname, encoding="utf8") as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index= "dev_data")

# %%
fname = 'uk_listings.csv'
with open(fname, encoding="utf8") as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index= "uk")

# %%
fname = 'school_info.csv'
with open(fname, encoding="utf8") as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index= "school")

# %%
fname = 'developer_reviews.csv'
with open(fname, encoding="utf8") as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index= "developer_rev")

# %%
fname = '../Scripts/school_data/2018-2019/2018-2019_england_ks2final.csv'
with open(fname, encoding="utf8") as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index= "school_ks2")

# %%
fname = '../Scripts/school_data/2018-2019/Ofsted_Rating_Data.csv'
with open(fname) as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index= "school_ofsted")

# %%
fname = '../Scripts/school_data/2018-2019/school_coordinates_images.csv'
with open(fname, encoding="utf8") as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index= "school_coords")

# %%
fname = '../Scripts/school_data/2021-2022/england_census.csv'
with open(fname, encoding="utf8") as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index= "school_census")

# %%
fname = '../Scripts/school_data/2021-2022/england_abs.csv'
with open(fname, encoding="utf8") as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index= "school_absence")

# %%
fname = '../Scripts/school_data/2021-2022/england_apprentice-achievement-rates.csv'
with open(fname, encoding="utf8") as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index= "school_apprentice")

# %%
fname = '../Scripts/school_data/2021-2022/england_ks4final.csv'
with open(fname, encoding="utf8") as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index= "school_ks4")

# %%
demographics = ['accomodation_type', 'age', 'country_of_birth', 'economic_activity', 'ethnic_group', 'health', 'ns_sec', 'partnership_status', 'religion', 'sex', 'tenure']
for i in demographics:
    fname = "../Scripts/demographics_data/"+i+".csv"
    ind = "demo_"+i
    with open(fname, encoding="utf8") as f:
        reader = csv.DictReader(f)
        helpers.bulk(es, reader, index= ind)
    print("Data added for",i)

# %%
csv_list = os.listdir('../Scripts/school_data/financial_files')
# fname = '../Scripts/school_data/financial_data.csv'
for fname in csv_list:
    fname = '../Scripts/school_data/financial_files/'+fname
    with open(fname, encoding="utf8") as f:
        reader = csv.DictReader(f)
        helpers.bulk(es, reader, index= "school_fin")
    print(csv_list.index(fname)+1, end=" ")
    helpers.bulk(es, action_list)

# %%
fname = '../Scripts/crime_data/crime_data.csv'
with open(fname, encoding="utf8") as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index= "crime")
# Out:
# D:\ASUS\Anaconda\lib\site-packages\urllib3\connectionpool.py:853: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn((
# D:\ASUS\Anaconda\lib\site-packages\urllib3\connectionpool.py:853: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn((
# D:\ASUS\Anaconda\lib\site-packages\urllib3\connectionpool.py:853: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   warnings.warn((
# ...

# %%
fname = '../Scripts/PS1_data.csv'
with open(fname) as f:
    reader = csv.DictReader(f)
    helpers.bulk(es, reader, index= "plan_stats")

# %%
# files = ['../Scripts/postcode/England1postcodes.csv', '../Scripts/postcode/England2postcodes.csv']
for i in range(2,201):
    fname = "../Scripts/postcode/England1postcodes-" + str(i) + ".csv"
    with open(fname) as f:
        reader = csv.DictReader(f)
        helpers.bulk(es, reader, index= "postcode")
    print("Data added for",i)

# %%
warnings.simplefilter('ignore')
#Getting the list of all folders
subdirs = os.listdir('../Scripts/all-domestic-certificates')
subdir = subdirs[190:-3]
for i in subdir:
#     fname = '../Scripts/all-domestic-certificates/'+i+'/certificates.csv'
    fname = '../Scripts/all-domestic-certificates/'+i+'/recommendations.csv'
    with open(fname, encoding="utf8") as f:
        reader = csv.DictReader(f)
        helpers.bulk(es, reader, index= "epc_reco")
    print("Data added for",i)
# Out:
# Data added for domestic-E07000170-Ashfield
# Data added for domestic-E07000171-Bassetlaw
# Data added for domestic-E07000172-Broxtowe
# Data added for domestic-E07000173-Gedling

# %%
# %run zoopla.py

# %%
df = pd.read_csv('../Scripts/school_data/2021-2022/england_abs.csv')
df.head()

# %%
df = df.iloc[:,:5]
df.head()

# %%
df.to_csv('../Scripts/school_data/2021-2022/england_abs.csv',index=False)

# %%
subdirs = os.listdir('../Scripts/all-domestic-certificates')
subdirs.index("domestic-E07000169-Selby")
# Out:
# 189

# %%
41, 268, 282, 296, 300, 302, 315
